# %%
import os
directory = "add_directory_here"
os.chdir(directory)
import visualkeras
from collections import defaultdict
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, ZeroPadding2D, BatchNormalization
from Scripts import Model_Training as mt




model = mt.model_load('Models\CNN_Complex_allf_f_0pad.h5')
color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'lightseagreen'
color_map[MaxPooling2D]['fill'] = 'gold'
color_map[Dense]['fill'] = 'plum'


visualkeras.layered_view(model, type_ignore=[ZeroPadding2D, Dropout, Flatten, BatchNormalization], color_map=color_map, spacing = 20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 128, 81, 32)       320
#
#  batch_normalization (BatchN  (None, 128, 81, 32)      128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 81, 32)       9248
#
#  batch_normalization_1 (Batc  (None, 128, 81, 32)      128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 40, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 40, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 40, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 64, 40, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 64, 40, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 64, 40, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 20, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 20, 64)        0
#
# ...
